# %% [markdown]
# ### In the Hangman game, the user is given 6 chances to guess the correct letter in a randomly selected name from a list of names.
# ### If the user guessed the correct letter, the game continues, if not the user loses a life.

# %%
import random

stages = ['''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========
''', '''
  +---+
  |   |
      |
      |
      |
      |
=========
''']

end_of_game = False
word_list = ["ardvark", "baboon", "camel"]
chosen_word = random.choice(word_list)
word_length = len(chosen_word)

#keeping track of num of lives
lives = 6

#Create blanks
display = []
for _ in range(word_length):
    display += "_"

while not end_of_game:
    guess = input("Guess a letter: ").lower()
    
    if guess in display:
        print(f"you have already guessed this letter {guess}")

    #Check guessed letter
    for position in range(word_length):
        letter = chosen_word[position]
        if letter == guess:
            display[position] = letter

    #If guess is not a letter in the chosen_word,
    #Then reduce 'lives' by 1. 
    if guess not in chosen_word:
        print(f"You guessed {guess}, that's not in the word, you lose a life")
        
        lives -= 1
        if lives == 0:
            end_of_game = True
            print("You lose.")
            

    #Join all the elements in the list and turn it into a String.
    print(f"{' '.join(display)}")

    
    #Check if user has got all letters.
    if "_" not in display:
        end_of_game = True
        print("You win.")

    print(stages[lives])
# Out:
# Guess a letter: w
# You guessed w, that's not in the word, you lose a life
# _ _ _ _ _
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# ...
#
# Guess a letter: z
# You guessed z, that's not in the word, you lose a life
# _ _ _ _ _
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# ...
#
# Guess a letter: q
# You guessed q, that's not in the word, you lose a life
# _ _ _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# ...
# Guess a letter: s
# You guessed s, that's not in the word, you lose a life
# _ _ _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# ...
#
# Guess a letter: q
# You guessed q, that's not in the word, you lose a life
# _ _ _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# ...
#
# Guess a letter: e
# _ _ _ e _
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# ...
#
# Guess a letter: q
# You guessed q, that's not in the word, you lose a life
# You lose.
# _ _ _ e _
#
#   +---+
#   |   |
#   O   |
# ...
